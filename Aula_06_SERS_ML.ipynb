# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasBellezzo/CP02_PCP/blob/master/Aula_06_SERS_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Modelo de classificação
#
# Treinar um modelo preditivo de classificação utilizando o algorítmo Regressão Logística
#
#
# (Logistic Regression do sklearn)
#
# Para prever se a rede elétrica está instável ou estável com os dados fornecidos.

# %% [markdown]
# ## Preparando ambiente:

# %%
# Preparação do ambiente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Algoritmo de regressão logística
from sklearn.linear_model import LogisticRegression

# Função que permite separação de treino e teste
from sklearn.model_selection import train_test_split

# Métricas para classificação
from sklearn.metrics import accuracy_score

# Matriz e confusão
from sklearn.metrics import confusion_matrix

# %%
# Carregar os dados e criar um DF (DataFrame)
dados = pd.read_csv('https://raw.githubusercontent.com/LucasBellezzo/Checkpoint02-SERS-1CCPQ/refs/heads/main/Data_for_UCI_named.csv')

# %%
dados.head(10)
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# 5  6.999209  9.109247  3.784066  4.267788  4.429669 -1.857139 -0.670397
# 6  6.710166  3.765204  6.929314  8.818562  2.397419 -0.614590 -1.208826
# 7  6.953512  1.379125  5.719400  7.870307  3.224495 -0.748998 -1.186517
# 8  4.689852  4.007747  1.478573  3.733787  4.041300 -1.410344 -1.238204
# 9  9.841496  1.413822  9.769856  7.641616  4.727595 -1.991363 -0.857637
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# ...

# %%
# Inspeção básica
dados.shape
# Out:
# (10000, 14)

# %%
dados.info
# Out:
# <bound method DataFrame.info of           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
dados.columns
# Out:
# Index(['tau1', 'tau2', 'tau3', 'tau4', 'p1', 'p2', 'p3', 'p4', 'g1', 'g2',
#        'g3', 'g4', 'stab', 'stabf'],
#       dtype='object')

# %%
# Estatisticas descritivas
# Somente atributos categóricos

dados.describe(include='object')
# Out:
#            stabf
# count      10000
# unique         2
# top     unstable
# freq        6380

# %%
# Quais as classes temos no atributo 'stabf'?
dados['stabf'].unique()
# Out:
# array(['unstable', 'stable'], dtype=object)

# %%
# Quantos registros temos de cada classe em 'stabf'?
dados['stabf'].value_counts()
# Out:
# stabf
# unstable    6380
# stable      3620
# Name: count, dtype: int64

# %%
# Dados de entrada X -------> Features -------> Dataframes
# Variáveis independentes

X = dados.drop(['stab', 'stabf'], axis=1)
X.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923

# %%
dados['stabf'] = dados['stabf'].replace({'unstable': 'INSTÁVEL','stable': 'ESTÁVEL'} )

# %%
dados['stabf'].value_counts()
# Out:
# stabf
# INSTÁVEL    6380
# ESTÁVEL     3620
# Name: count, dtype: int64

# %%
# Dados de saída y --------> Target ---------> oque vamos prever
# Variável dependente

y = dados['stabf']
y
# Out:
# 0       INSTÁVEL
# 1        ESTÁVEL
# 2       INSTÁVEL
# 3       INSTÁVEL
# 4       INSTÁVEL
#           ...
# 9995    INSTÁVEL
# 9996     ESTÁVEL
# 9997     ESTÁVEL
# 9998    INSTÁVEL
# 9999    INSTÁVEL
# Name: stabf, Length: 10000, dtype: object
